# %% [markdown]
# <a href="https://colab.research.google.com/github/DrabberSP/Extracci-n-de-datos/blob/main/1_Extracci%C3%B3n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
# Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
# Convertir en dataframe
df=pd.read_csv("file.csv")
df
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# 1        2005          1           Nacional  Mujeres
# 2        2005          1     Aguascalientes  Hombres
# 3        2005          1     Aguascalientes  Mujeres
# 4        2005          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# ...

# %%
# Imprimimos primeras 5
df.head(5)

# %% [markdown]
# **Filtros básicos para variables cualitativas**

# %%
# Filtros por objeto 
filtro1=df[df["Sexo"]=="Mujeres"]
filtro1

# %%
# Filtro por filas (no consecutivas)
#filtro2= df.iloc[300;302,:] 
filtro2= df.iloc[[1000,2000,3000], :] 
filtro2
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 1000     2008          4           Coahuila  Hombres
# 2000     2012          3            Durango  Hombres
# 3000     2016          2             M xico  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1000                                          162606            694961
# 2000                                           76715            433701
# 3000                                          807150           4305995
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 1000                        23.397859740000000000000
# 2000                        17.688453570000000000000
# 3000                         18.74479650000000000000

# %%
# Filtro por filas (consecutivas)
filtro2= df.iloc[0:99,:] 
#filtro2= df.iloc[[1000,2000,3000], :] 
filtro2
# Out:
#     Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0      2005          1           Nacional  Hombres
# 1      2005          1           Nacional  Mujeres
# 2      2005          1     Aguascalientes  Hombres
# 3      2005          1     Aguascalientes  Mujeres
# 4      2005          1    Baja California  Hombres
# ..      ...        ...                ...      ...
# 94     2005          2            Jalisco  Hombres
# 95     2005          2            Jalisco  Mujeres
# 96     2005          2             M xico  Hombres
# 97     2005          2             M xico  Mujeres
# 98     2005          2          Michoac n  Hombres
#
#    Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                          4384907          26597801
# 1                                          2690296          14843275
# 2                                            56407            246177
# 3                                            28430            145656
# ...

# %%
# Filtro por columnas (consecutivas)
filtro3= df.iloc[:, 4:6] 
filtro3
# Out:
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# 3                                              28430            145656
# 4                                             167651            768989
# ...                                              ...               ...
# 4549                                          107640           1190733
# 4550                                          101992            691397
# 4551                                           82759            478943
# 4552                                           44105            402326
# 4553                                           39472            255761
#
# [4554 rows x 2 columns]

# %%
# Filtro por columnas (no consecutivas)
filtro3= df.iloc[:,[1,4,6]] 
filtro3
# Out:
#       Trimestre Poblacion_ocupada_en_la_industria_manufacturera  \
# 0             1                                         4384907
# 1             1                                         2690296
# 2             1                                           56407
# 3             1                                           28430
# 4             1                                          167651
# ...         ...                                             ...
# 4549          1                                          107640
# 4550          1                                          101992
# 4551          1                                           82759
# 4552          1                                           44105
# 4553          1                                           39472
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                           16.485975660000000000000
# 1                           18.124679360000000000000
# ...

# %%
# Filtro por columnas y por filas
filtro_mix= df.iloc[[10,20,50], 2:5]
filtro_mix
# Out:
#    Entidad_Federativa     Sexo Poblacion_ocupada_en_la_industria_manufacturera
# 10           Coahuila  Hombres                                          171196
# 20            Durango  Hombres                                           65926
# 50            Sinaloa  Hombres                                           77990

# %%
# Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded['file.csv']), index_col=2)
df

# %%
# Paso 2
filtro4= df.loc[["Puebla", "Durango"],["Poblacion_ocupada_en_la_industria_manufacturera"]]
filtro4

# %%
# Filtro por cabecera
filtro5=df.head()
filtro5

# %% [markdown]
# **Filtros básicos para variables cuantitativas**

# %%
# Filtro por comparación
filtro6=df[df['Periodo']>2010]
filtro6

# %% [markdown]
# **Filtros básicos con conectores lógicos**

# %%
# Filtro Y
filtro7=df[(df["Periodo"]==2015) & (df["Sexo"] == "Hombres") & (df["Entidad_Federativa"] == "Puebla")]
filtro7
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 2682     2015          1             Puebla  Hombres
# 2748     2015          2             Puebla  Hombres
# 2814     2015          3             Puebla  Hombres
# 2880     2015          4             Puebla  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 2682                                          213571           1549409
# 2748                                          209708           1602273
# 2814                                          231235           1559704
# 2880                                          228012           1619413
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 2682                        13.784029910000000000000
# 2748                        13.088156640000000000000
# 2814                        14.825569470000000000000
# 2880                        14.079916610000000000000

# %%
# Filtro O
filtro8=df[(df["Periodo"]>2006)|(df["Sexo"]=="Mujeres")]
filtro8
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 1        2005          1             Nacional  Mujeres
# 3        2005          1       Aguascalientes  Mujeres
# 5        2005          1      Baja California  Mujeres
# 7        2005          1  Baja California Sur  Mujeres
# 9        2005          1             Campeche  Mujeres
# ...       ...        ...                  ...      ...
# 4549     2022          1             Veracruz  Mujeres
# 4550     2022          1              Yucat n  Hombres
# 4551     2022          1              Yucat n  Mujeres
# 4552     2022          1            Zacatecas  Hombres
# 4553     2022          1            Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1                                            2690296          14843275
# 3                                              28430            145656
# 5                                             103697            398911
# ...

# %%
# Filtro not
filtro9=df[~(df["Periodo"]>2006)& ~(df["Sexo"]=="Mujeres")]
filtro9
# Out:
#      Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 0       2005          1             Nacional  Hombres
# 2       2005          1       Aguascalientes  Hombres
# 4       2005          1      Baja California  Hombres
# 6       2005          1  Baja California Sur  Hombres
# 8       2005          1             Campeche  Hombres
# ..       ...        ...                  ...      ...
# 518     2006          4           Tamaulipas  Hombres
# 520     2006          4             Tlaxcala  Hombres
# 522     2006          4             Veracruz  Hombres
# 524     2006          4              Yucat n  Hombres
# 526     2006          4            Zacatecas  Hombres
#
#     Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                           4384907          26597801
# 2                                             56407            246177
# 4                                            167651            768989
# ...

# %%
# Convertir archivo filtrado a csv
filtro9.to_csv("Entregable1.csv")

# %%
# Descargar archivo filtrado en csv
from google.colab import files
files.download("Entregable1.csv")
